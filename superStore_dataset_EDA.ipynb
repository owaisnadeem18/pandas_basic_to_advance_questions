# %% [markdown]
# ## 📦 Dataset
#
# We will use the **Superstore Sales Dataset**:
# 🔗 [Kaggle Link](https://www.kaggle.com/datasets/vivek468/superstore-dataset-final)

# %%
import numpy as np
import pandas as pd

# Load dataset (path placeholder)
url = "https://raw.githubusercontent.com/leonism/sample-superstore/master/data/superstore.csv"

df = pd.read_csv(url)
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156   11/8/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156   11/8/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688   6/12/2017   6/16/2017    Second Class
# 3          4  US-2016-108966  10/11/2016  10/18/2016  Standard Class
# 4          5  US-2016-108966  10/11/2016  10/18/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 10795    Yes  US-2018-147886         NaN         NaN             NaN
# 10796    Yes  US-2018-147998         NaN         NaN             NaN
# 10797    Yes  US-2018-151127         NaN         NaN             NaN
# 10798    Yes  US-2018-155999         NaN         NaN             NaN
# 10799    Yes  US-2018-155999         NaN         NaN             NaN
#
#       Customer ID    Customer Name    Segment        Country             City  \
# 0        CG-12520      Claire Gute   Consumer  United States        Henderson
# 1        CG-12520      Claire Gute   Consumer  United States        Henderson
# 2        DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3        SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4        SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...           ...              ...        ...            ...              ...
# 10795         NaN              NaN        NaN            NaN              NaN
# 10796         NaN              NaN        NaN            NaN              NaN
# 10797         NaN              NaN        NaN            NaN              NaN
# 10798         NaN              NaN        NaN            NaN              NaN
# 10799         NaN              NaN        NaN            NaN              NaN
#
#        ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0      ...     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1      ...     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2      ...     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3      ...     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4      ...     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# ...    ...         ...     ...              ...              ...          ...
# 10795  ...         NaN     NaN              NaN              NaN          NaN
# 10796  ...         NaN     NaN              NaN              NaN          NaN
# 10797  ...         NaN     NaN              NaN              NaN          NaN
# 10798  ...         NaN     NaN              NaN              NaN          NaN
# 10799  ...         NaN     NaN              NaN              NaN          NaN
#
#                                             Product Name     Sales  Quantity  \
# 0                      Bush Somerset Collection Bookcase  261.9600       2.0
# 1      Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2      Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3          Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                         Eldon Fold 'N Roll Cart System   22.3680       2.0
# ...                                                  ...       ...       ...
# 10795                                                NaN       NaN       NaN
# 10796                                                NaN       NaN       NaN
# 10797                                                NaN       NaN       NaN
# 10798                                                NaN       NaN       NaN
# 10799                                                NaN       NaN       NaN
#
#        Discount    Profit
# 0          0.00   41.9136
# 1          0.00  219.5820
# 2          0.00    6.8714
# 3          0.45 -383.0310
# 4          0.20    2.5164
# ...         ...       ...
# 10795       NaN       NaN
# 10796       NaN       NaN
# 10797       NaN       NaN
# 10798       NaN       NaN
# 10799       NaN       NaN
#
# [10800 rows x 21 columns]

# %%
df["Segment"]
# Out:
# 0         Consumer
# 1         Consumer
# 2        Corporate
# 3         Consumer
# 4         Consumer
#            ...
# 10795          NaN
# 10796          NaN
# 10797          NaN
# 10798          NaN
# 10799          NaN
# Name: Segment, Length: 10800, dtype: object

# %% [markdown]
# ## 🧹 Data Cleaning & Preparation
#
# - Checking nulls
# - Renaming columns
# - Converting data types
# - Filtering records

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10800 non-null  object
#  1   Order ID       10800 non-null  object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   float64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(5), object(16)
# memory usage: 1.7+ MB

# %%
df.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date       806
# Ship Date        806
# Ship Mode        806
# Customer ID      806
# Customer Name    806
# Segment          806
# Country          806
# City             806
# State            806
# Postal Code      817
# Region           806
# Product ID       806
# Category         806
# Sub-Category     806
# Product Name     806
# Sales            806
# Quantity         806
# Discount         806
# Profit           806
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID            object
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity         float64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.head()
# Out:
#   Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0      1  CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156   11/8/2017  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688   6/12/2017   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966  10/11/2016  10/18/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df.head()
# Out:
#   Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10800 non-null  object
#  1   Order ID       10800 non-null  object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   float64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(15)
# memory usage: 1.7+ MB

# %%
df.columns = df.columns.str.replace(" " , "_").str.lower()

# %%
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub-category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# row_id             0
# order_id           0
# order_date       806
# ship_date        806
# ship_mode        806
# customer_id      806
# customer_name    806
# segment          806
# country          806
# city             806
# state            806
# postal_code      817
# region           806
# product_id       806
# category         806
# sub-category     806
# product_name     806
# sales            806
# quantity         806
# discount         806
# profit           806
# dtype: int64

# %% [markdown]
# ## 🔍 GroupBy: Split-Apply-Combine Paradigm
#
# | Step | Description | Output |
# |------|-------------|--------|
# | Split | Group data by column(s) | `DataFrameGroupBy` object |
# | Apply | Run aggregation/transformation/filter | Group results |
# | Combine | Merge into final structure | Tidy DataFrame |

# %% [markdown]
# ### 🧮 Average Sales by Region

# %%
df.head(29)
# Out:
#    row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 10     11  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 11     12  CA-2015-115812 2015-06-09   6/14/2015  Standard Class    BH-11710
# 12     13  CA-2018-114412 2018-04-15   4/20/2018  Standard Class    AA-10480
# 13     14  CA-2017-161389 2017-12-05  12/10/2017  Standard Class    IM-15070
# 14     15  US-2016-118983 2016-11-22  11/26/2016  Standard Class    HP-14815
# 15     16  US-2016-118983 2016-11-22  11/26/2016  Standard Class    HP-14815
# 16     17  CA-2015-105893 2015-11-11  11/18/2015  Standard Class    PK-19075
# 17     18  CA-2015-167164 2015-05-13   5/15/2015    Second Class    AG-10270
# 18     19  CA-2015-143336 2015-08-27    9/1/2015    Second Class    ZD-21925
# 19     20  CA-2015-143336 2015-08-27    9/1/2015    Second Class    ZD-21925
# 20     21  CA-2015-143336 2015-08-27    9/1/2015    Second Class    ZD-21925
# 21     22  CA-2017-137330 2017-12-09  12/13/2017  Standard Class    KB-16585
# 22     23  CA-2017-137330 2017-12-09  12/13/2017  Standard Class    KB-16585
# 23     24  US-2018-156909 2018-07-16   7/18/2018    Second Class    SF-20065
# 24     25  CA-2016-106320 2016-09-25   9/30/2016  Standard Class    EB-13870
# 25     26  CA-2017-121755 2017-01-16   1/20/2017    Second Class    EH-13945
# 26     27  CA-2017-121755 2017-01-16   1/20/2017    Second Class    EH-13945
# 27     28  US-2016-150630 2016-09-17   9/21/2016  Standard Class    TB-21520
# 28     29  US-2016-150630 2016-09-17   9/21/2016  Standard Class    TB-21520
#
#          customer_name      segment        country             city  ...  \
# 0          Claire Gute     Consumer  United States        Henderson  ...
# 1          Claire Gute     Consumer  United States        Henderson  ...
# 2      Darrin Van Huff    Corporate  United States      Los Angeles  ...
# 3       Sean O'Donnell     Consumer  United States  Fort Lauderdale  ...
# 4       Sean O'Donnell     Consumer  United States  Fort Lauderdale  ...
# 5      Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 6      Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 7      Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 8      Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 9      Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 10     Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 11     Brosina Hoffman     Consumer  United States      Los Angeles  ...
# 12        Andrew Allen     Consumer  United States          Concord  ...
# 13        Irene Maddox     Consumer  United States          Seattle  ...
# 14       Harold Pawlan  Home Office  United States       Fort Worth  ...
# 15       Harold Pawlan  Home Office  United States       Fort Worth  ...
# 16           Pete Kriz     Consumer  United States          Madison  ...
# 17     Alejandro Grove     Consumer  United States      West Jordan  ...
# 18  Zuschuss Donatelli     Consumer  United States    San Francisco  ...
# 19  Zuschuss Donatelli     Consumer  United States    San Francisco  ...
# 20  Zuschuss Donatelli     Consumer  United States    San Francisco  ...
# 21           Ken Black    Corporate  United States          Fremont  ...
# 22           Ken Black    Corporate  United States          Fremont  ...
# 23     Sandra Flanagan     Consumer  United States     Philadelphia  ...
# 24         Emily Burns     Consumer  United States             Orem  ...
# 25       Eric Hoffmann     Consumer  United States      Los Angeles  ...
# 26       Eric Hoffmann     Consumer  United States      Los Angeles  ...
# 27     Tracy Blumstein     Consumer  United States     Philadelphia  ...
# 28     Tracy Blumstein     Consumer  United States     Philadelphia  ...
#
#    postal_code   region       product_id         category sub-category  \
# 0      42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0    South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0    South  OFF-ST-10000760  Office Supplies      Storage
# 5      90032.0     West  FUR-FU-10001487        Furniture  Furnishings
# 6      90032.0     West  OFF-AR-10002833  Office Supplies          Art
# 7      90032.0     West  TEC-PH-10002275       Technology       Phones
# 8      90032.0     West  OFF-BI-10003910  Office Supplies      Binders
# 9      90032.0     West  OFF-AP-10002892  Office Supplies   Appliances
# 10     90032.0     West  FUR-TA-10001539        Furniture       Tables
# 11     90032.0     West  TEC-PH-10002033       Technology       Phones
# 12     28027.0    South  OFF-PA-10002365  Office Supplies        Paper
# 13     98103.0     West  OFF-BI-10003656  Office Supplies      Binders
# 14     76106.0  Central  OFF-AP-10002311  Office Supplies   Appliances
# 15     76106.0  Central  OFF-BI-10000756  Office Supplies      Binders
# 16     53711.0  Central  OFF-ST-10004186  Office Supplies      Storage
# 17     84084.0     West  OFF-ST-10000107  Office Supplies      Storage
# 18     94109.0     West  OFF-AR-10003056  Office Supplies          Art
# 19     94109.0     West  TEC-PH-10001949       Technology       Phones
# 20     94109.0     West  OFF-BI-10002215  Office Supplies      Binders
# 21     68025.0  Central  OFF-AR-10000246  Office Supplies          Art
# 22     68025.0  Central  OFF-AP-10001492  Office Supplies   Appliances
# 23     19140.0     East  FUR-CH-10002774        Furniture       Chairs
# 24     84057.0     West  FUR-TA-10000577        Furniture       Tables
# 25     90049.0     West  OFF-BI-10001634  Office Supplies      Binders
# 26     90049.0     West  TEC-AC-10003027       Technology  Accessories
# 27     19140.0     East  FUR-BO-10004834        Furniture    Bookcases
# 28     19140.0     East  OFF-BI-10000474  Office Supplies      Binders
#
#                                          product_name      sales  quantity  \
# 0                   Bush Somerset Collection Bookcase   261.9600       2.0
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400       3.0
# 2   Self-Adhesive Address Labels for Typewriters b...    14.6200       2.0
# 3       Bretford CR4500 Series Slim Rectangular Table   957.5775       5.0
# 4                      Eldon Fold 'N Roll Cart System    22.3680       2.0
# 5   Eldon Expressions Wood and Plastic Desk Access...    48.8600       7.0
# 6                                          Newell 322     7.2800       4.0
# 7                      Mitel 5320 IP Phone VoIP phone   907.1520       6.0
# 8   DXL Angle-View Binders with Locking Rings by S...    18.5040       3.0
# 9                    Belkin F5C206VTEL 6 Outlet Surge   114.9000       5.0
# 10           Chromcraft Rectangular Conference Tables  1706.1840       9.0
# 11      Konftel 250 Conference phone - Charcoal black   911.4240       4.0
# 12                                         Xerox 1967    15.5520       3.0
# 13        Fellowes PB200 Plastic Comb Binding Machine   407.9760       3.0
# 14  Holmes Replacement Filter for HEPA Air Cleaner...    68.8100       5.0
# 15   Storex DuraTech Recycled Plastic Frosted Binders     2.5440       3.0
# 16  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...   665.8800       6.0
# 17                         Fellowes Super Stor/Drawer    55.5000       2.0
# 18                                         Newell 341     8.5600       2.0
# 19                            Cisco SPA 501G IP Phone   213.4800       3.0
# 20        Wilson Jones Hanging View Binder, White, 1"    22.7200       4.0
# 21                                         Newell 318    19.4600       7.0
# 22        Acco Six-Outlet Power Strip, 4' Cord Length    60.3400       7.0
# 23                 Global Deluxe Stacking Chair, Gray    71.3720       2.0
# 24      Bretford CR4500 Series Slim Rectangular Table  1044.6300       3.0
# 25                    Wilson Jones Active Use Binders    11.6480       2.0
# 26   Imation 8GB Mini TravelDrive USB 2.0 Flash Drive    90.5700       3.0
# 27  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.4300       7.0
# 28  Avery Recycled Flexi-View Covers for Binding S...     9.6180       2.0
#
#     discount     profit
# 0       0.00    41.9136
# 1       0.00   219.5820
# 2       0.00     6.8714
# 3       0.45  -383.0310
# 4       0.20     2.5164
# 5       0.00    14.1694
# 6       0.00     1.9656
# 7       0.20    90.7152
# 8       0.20     5.7825
# 9       0.00    34.4700
# 10      0.20    85.3092
# 11      0.20    68.3568
# 12      0.20     5.4432
# 13      0.20   132.5922
# 14      0.80  -123.8580
# 15      0.80    -3.8160
# 16      0.00    13.3176
# 17      0.00     9.9900
# 18      0.00     2.4824
# 19      0.20    16.0110
# 20      0.20     7.3840
# 21      0.00     5.0596
# 22      0.00    15.6884
# 23      0.30    -1.0196
# 24      0.00   240.2649
# 25      0.20     4.2224
# 26      0.00    11.7741
# 27      0.50 -1665.0522
# 28      0.70    -7.0532
#
# [29 rows x 21 columns]

# %%
df.groupby("region")["sales"].mean()
# Out:
# region
# Central    215.772661
# East       238.336110
# South      241.803645
# West       226.493233
# Name: sales, dtype: float64

# %% [markdown]
# ### 📊 Total Profit by Category & Sub-Category

# %%
df.head()
# Out:
#   row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.groupby("region")

# %%
df.head()
# Out:
#   row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.groupby(["category" , "sub_category"])["profit"].sum().sort_values(ascending=False)
# Out:
# category         sub_category
# Technology       Copiers         55617.8249
#                  Phones          44515.7306
#                  Accessories     41936.6357
# Office Supplies  Paper           34053.5693
#                  Binders         30221.7633
# Furniture        Chairs          26590.1663
# Office Supplies  Storage         21278.8264
#                  Appliances      18138.0054
# Furniture        Furnishings     13059.1436
# Office Supplies  Envelopes        6964.1767
#                  Art              6527.7870
#                  Labels           5546.2540
# Technology       Machines         3384.7569
# Office Supplies  Fasteners         949.5182
#                  Supplies        -1189.0995
# Furniture        Bookcases       -3472.5560
#                  Tables         -17725.4811
# Name: profit, dtype: float64

# %% [markdown]
# ### 📐 Named Aggregation

# %%
df.head()
# Out:
#   row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub-category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.groupby("segment").agg(
    total_sales=("sales" , "sum"),
    avg_discount=("discount" , "mean"),
    order_count=("order_id" , "count")
)
# Out:
#               total_sales  avg_discount  order_count
# segment
# Consumer     1.161401e+06      0.158141         5191
# Corporate    7.061464e+05      0.158228         3020
# Home Office  4.296531e+05      0.147128         1783

# %% [markdown]
# ### 🧪 Custom Aggregation

# %%
df.groupby( "region")["profit"].agg(
    mean_profit = "mean",
    profit_range = lambda x: x.max() - x.min() 
    )
# Out:
#          mean_profit  profit_range
# region
# Central    17.092709    12101.8688
# East       32.135808    11639.9636
# South      28.857673     7017.4654
# West       33.849032    10119.9608

# %% [markdown]
# ### 🔁 Transform Example (Z-score)

# %%
df["sales_zscore"] = df.groupby("category")["sales"].transform(
    lambda x: (x - x.mean()) / x.std()
)
df[["category", "sales", "sales_zscore"]].head()
# Out:
#           category     sales  sales_zscore
# 0        Furniture  261.9600     -0.174639
# 1        Furniture  731.9400      0.759382
# 2  Office Supplies   14.6200     -0.273964
# 3        Furniture  957.5775      1.207806
# 4  Office Supplies   22.3680     -0.253691

# %% [markdown]
# ## 🧠 Assigned Tasks

# %% [markdown]
# Try solving these using the dataset:
#
# 1. Find total sales and average quantity for each `region`.
# 2. For each `category`, compute the standard deviation and CV of `sales`.
# 3. Create a column `high_discount` = `True` if `discount` > average discount for its segment.
# 4. Filter only those sub-categories where total `sales` > 10000.
# 5. Normalize `profit` within each category using min-max scaling.
# 6. Plot cumulative sales per region over time.

# %% [markdown]
# 1. Find total sales and average quantity for each `region`.

# %%
df.head()
# Out:
#   row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ... region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600      2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400      3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200      2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775      5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680      2.0
#
#    discount    profit  sales_zscore
# 0      0.00   41.9136     -0.174639
# 1      0.00  219.5820      0.759382
# 2      0.00    6.8714     -0.273964
# 3      0.45 -383.0310      1.207806
# 4      0.20    2.5164     -0.253691
#
# [5 rows x 22 columns]

# %%
df.head()
# Out:
#   row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ... region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600      2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400      3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200      2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775      5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680      2.0
#
#    discount    profit  sales_zscore
# 0      0.00   41.9136     -0.174639
# 1      0.00  219.5820      0.759382
# 2      0.00    6.8714     -0.273964
# 3      0.45 -383.0310      1.207806
# 4      0.20    2.5164     -0.253691
#
# [5 rows x 22 columns]

# %%
df["region"]
# Out:
# 0        South
# 1        South
# 2         West
# 3        South
# 4        South
#          ...
# 10795      NaN
# 10796      NaN
# 10797      NaN
# 10798      NaN
# 10799      NaN
# Name: region, Length: 10800, dtype: object

# %%
region_summary = df.groupby("region").agg(
    total_sales = ("sales" , "sum"),
    avg_quantity = ("quantity" , "mean")
)

region_summary
# Out:
#          total_sales  avg_quantity
# region
# Central  501239.8908      3.779595
# East     678781.2400      3.728230
# South    391721.9050      3.832716
# West     725457.8245      3.829535

# %%
# do practice of question task # 01 again:

# 1. Find total sales and average quantity for each `region`.

region_summ = df.groupby("region").agg(
    total_sales = ("sales" , "sum" ),
    quantity = ("quantity" , "mean" )
)

region_summ
# Out:
#          total_sales  quantity
# region
# Central  501239.8908  3.779595
# East     678781.2400  3.728230
# South    391721.9050  3.832716
# West     725457.8245  3.829535

# %% [markdown]
# 2. For each `category`, compute the standard deviation and CV of `sales`.

# %%
category_summary = df.groupby("category").agg(
    sales_std = ("sales", "std"),
    sales_cv = ("sales" , lambda x: x.std() / x.mean()) # coefficeint formula is Std Deviation / mean
)

category_summary
# Out:
#                    sales_std  sales_cv
# category
# Furniture         503.179145  1.438333
# Office Supplies   382.182228  3.202892
# Technology       1108.655848  2.448936

# %% [markdown]
# 3. Create a column `high_discount` = `True` if `discount` > average discount for its segment.

# %%
df.head()
# Out:
#   row_id        order_id order_date   ship_date       ship_mode customer_id  \
# 0      1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1      2  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2      3  CA-2017-138688 2017-06-12   6/16/2017    Second Class    DV-13045
# 3      4  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
# 4      5  US-2016-108966 2016-10-11  10/18/2016  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ... region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         product_id         category sub_category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600      2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400      3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200      2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775      5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680      2.0
#
#    discount    profit  sales_zscore
# 0      0.00   41.9136     -0.174639
# 1      0.00  219.5820      0.759382
# 2      0.00    6.8714     -0.273964
# 3      0.45 -383.0310      1.207806
# 4      0.20    2.5164     -0.253691
#
# [5 rows x 22 columns]

# %%
avg_discount = df.groupby('segment')["discount"].transform("mean")

df["high_discount"] = (
    df["discount"] > avg_discount
)

avg_discount
# Out:
# 0        0.158141
# 1        0.158141
# 2        0.158228
# 3        0.158141
# 4        0.158141
#            ...
# 10795         NaN
# 10796         NaN
# 10797         NaN
# 10798         NaN
# 10799         NaN
# Name: discount, Length: 10800, dtype: float64

# %%
df
# Out:
#       row_id        order_id order_date   ship_date       ship_mode  \
# 0          1  CA-2017-152156 2017-11-08  11/11/2017    Second Class
# 1          2  CA-2017-152156 2017-11-08  11/11/2017    Second Class
# 2          3  CA-2017-138688 2017-06-12   6/16/2017    Second Class
# 3          4  US-2016-108966 2016-10-11  10/18/2016  Standard Class
# 4          5  US-2016-108966 2016-10-11  10/18/2016  Standard Class
# ...      ...             ...        ...         ...             ...
# 10795    Yes  US-2018-147886        NaT         NaN             NaN
# 10796    Yes  US-2018-147998        NaT         NaN             NaN
# 10797    Yes  US-2018-151127        NaT         NaN             NaN
# 10798    Yes  US-2018-155999        NaT         NaN             NaN
# 10799    Yes  US-2018-155999        NaT         NaN             NaN
#
#       customer_id    customer_name    segment        country             city  \
# 0        CG-12520      Claire Gute   Consumer  United States        Henderson
# 1        CG-12520      Claire Gute   Consumer  United States        Henderson
# 2        DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3        SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4        SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...           ...              ...        ...            ...              ...
# 10795         NaN              NaN        NaN            NaN              NaN
# 10796         NaN              NaN        NaN            NaN              NaN
# 10797         NaN              NaN        NaN            NaN              NaN
# 10798         NaN              NaN        NaN            NaN              NaN
# 10799         NaN              NaN        NaN            NaN              NaN
#
#        ...       product_id         category sub_category  \
# 0      ...  FUR-BO-10001798        Furniture    Bookcases
# 1      ...  FUR-CH-10000454        Furniture       Chairs
# 2      ...  OFF-LA-10000240  Office Supplies       Labels
# 3      ...  FUR-TA-10000577        Furniture       Tables
# 4      ...  OFF-ST-10000760  Office Supplies      Storage
# ...    ...              ...              ...          ...
# 10795  ...              NaN              NaN          NaN
# 10796  ...              NaN              NaN          NaN
# 10797  ...              NaN              NaN          NaN
# 10798  ...              NaN              NaN          NaN
# 10799  ...              NaN              NaN          NaN
#
#                                             product_name     sales quantity  \
# 0                      Bush Somerset Collection Bookcase  261.9600      2.0
# 1      Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400      3.0
# 2      Self-Adhesive Address Labels for Typewriters b...   14.6200      2.0
# 3          Bretford CR4500 Series Slim Rectangular Table  957.5775      5.0
# 4                         Eldon Fold 'N Roll Cart System   22.3680      2.0
# ...                                                  ...       ...      ...
# 10795                                                NaN       NaN      NaN
# 10796                                                NaN       NaN      NaN
# 10797                                                NaN       NaN      NaN
# 10798                                                NaN       NaN      NaN
# 10799                                                NaN       NaN      NaN
#
#       discount    profit  sales_zscore  high_discount
# 0         0.00   41.9136     -0.174639          False
# 1         0.00  219.5820      0.759382          False
# 2         0.00    6.8714     -0.273964          False
# 3         0.45 -383.0310      1.207806           True
# 4         0.20    2.5164     -0.253691           True
# ...        ...       ...           ...            ...
# 10795      NaN       NaN           NaN          False
# 10796      NaN       NaN           NaN          False
# 10797      NaN       NaN           NaN          False
# 10798      NaN       NaN           NaN          False
# 10799      NaN       NaN           NaN          False
#
# [10800 rows x 23 columns]

# %% [markdown]
# 4. Filter only those sub-categories where total `sales` > 10000.

# %%
# It gives the total summary of sales of each sub-category:
#  df.groupby("sub_category")["sales"].sum()

df.groupby("sub_category").filter(
    lambda x: x["sales"].sum() > 10000   
)
# Out:
#      row_id        order_id order_date   ship_date       ship_mode  \
# 0         1  CA-2017-152156 2017-11-08  11/11/2017    Second Class
# 1         2  CA-2017-152156 2017-11-08  11/11/2017    Second Class
# 2         3  CA-2017-138688 2017-06-12   6/16/2017    Second Class
# 3         4  US-2016-108966 2016-10-11  10/18/2016  Standard Class
# 4         5  US-2016-108966 2016-10-11  10/18/2016  Standard Class
# ...     ...             ...        ...         ...             ...
# 9989   9990  CA-2015-110422 2015-01-21   1/23/2015    Second Class
# 9990   9991  CA-2018-121258 2018-02-26    3/3/2018  Standard Class
# 9991   9992  CA-2018-121258 2018-02-26    3/3/2018  Standard Class
# 9992   9993  CA-2018-121258 2018-02-26    3/3/2018  Standard Class
# 9993   9994  CA-2018-119914 2018-05-04    5/9/2018    Second Class
#
#      customer_id     customer_name    segment        country             city  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ...       product_id         category sub_category  \
# 0     ...  FUR-BO-10001798        Furniture    Bookcases
# 1     ...  FUR-CH-10000454        Furniture       Chairs
# 2     ...  OFF-LA-10000240  Office Supplies       Labels
# 3     ...  FUR-TA-10000577        Furniture       Tables
# 4     ...  OFF-ST-10000760  Office Supplies      Storage
# ...   ...              ...              ...          ...
# 9989  ...  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...  TEC-PH-10003645       Technology       Phones
# 9992  ...  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name     sales quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600      2.0
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400      3.0
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200      2.0
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775      5.0
# 4                        Eldon Fold 'N Roll Cart System   22.3680      2.0
# ...                                                 ...       ...      ...
# 9989                             Ultra Door Pull Handle   25.2480      3.0
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600      2.0
# 9991                              Aastra 57i VoIP phone  258.5760      2.0
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000      4.0
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600      2.0
#
#      discount    profit  sales_zscore  high_discount
# 0        0.00   41.9136     -0.174639          False
# 1        0.00  219.5820      0.759382          False
# 2        0.00    6.8714     -0.273964          False
# 3        0.45 -383.0310      1.207806           True
# 4        0.20    2.5164     -0.253691           True
# ...       ...       ...           ...            ...
# 9989     0.20    4.1028     -0.645072           True
# 9990     0.00   15.6332     -0.512491          False
# 9991     0.20   19.3932     -0.175107           True
# 9992     0.00   13.3200     -0.234768          False
# 9993     0.00   72.9480      0.324023          False
#
# [9777 rows x 23 columns]

# %% [markdown]
# 5. Normalize `profit` within each category using min-max scaling

# %%
df["normalized_profit"] = df.groupby("category")["profit"].transform(
    lambda x: (x - x.min()) / (x.max() - x.min())
)

# %%
missing_values_summary = pd.DataFrame({
    "filled_values" : df.count(),
    "missing_values" : df.isnull().sum()
}) 

missing_values_summary
# Out:
#                filled_values  missing_values
# row_id                 10800               0
# order_id               10800               0
# order_date              9994             806
# ship_date               9994             806
# ship_mode               9994             806
# customer_id             9994             806
# customer_name           9994             806
# segment                 9994             806
# country                 9994             806
# city                    9994             806
# state                   9994             806
# postal_code             9983             817
# region                  9994             806
# product_id              9994             806
# category                9994             806
# sub_category            9994             806
# product_name            9994             806
# sales                   9994             806
# quantity                9994             806
# discount                9994             806
# profit                  9994             806
# sales_zscore            9994             806
# high_discount          10800               0
